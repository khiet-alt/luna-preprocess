# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd drive/MyDrive/khoa_luan/Seg_processing/
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/khoa_luan/Seg_processing
# annotations.csv  Processing.py	__pycache__  Untitled0.ipynb  util.py

# %%
# !pip install SimpleITK
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 MB 13.7 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
from Processing import getUids,createMask

# %%
# cads = pd.read_csv("annotations.csv")

# imgs = getUids(0, cads)

# %%
# !python  Processing.py
createMask(8)
# Out:
# 100%|██████████| 88/88 [09:49<00:00,  6.70s/it]

# %%
# !ls ../luna16/LUNA16
# Out:
# subset0  subset2  subset4  subset6  subset8  test
# subset1  subset3  subset5  subset7  subset9

# %%
# import os

# mask_files = os.listdir("../luna16/MASK/subset8")

# %%
# a = np.load("../luna16/MASK/subset8/" + mask_files[1])
# np.unique(a)

# %%
import glob
import os
import pandas as pd
from tqdm import tqdm
import numpy as np
from util import load_itk, world_2_voxel, voxel_2_world

# %%
# !ls ../../luna16/mask/subset5
# Out:
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.129567032250534530765928856531.npy
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.190144948425835566841437565646.npy
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.200841000324240313648595016964.npy
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.285926554490515269336267972830.npy
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.323408652979949774528873200770.npy
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.504845428620607044098514803031.npy

# %%
data_dir = "../../luna16"
i = 5
mask_paths = glob.glob(data_dir + f"/mask/subset{i}/*.npy")

mask_path = mask_paths[0]
print(mask_path)
a = np.load(mask_path)
# Out:
# ../../luna16/mask/subset5/1.3.6.1.4.1.14519.5.2.1.6279.6001.323408652979949774528873200770.npy

# %%
# a = a.T
a.shape
# Out:
# (133, 512, 512)

# %%
import matplotlib.pyplot as plt

for i in range(a.shape[0]):
  if 1 in a[i]:
    plt.imshow(a[i])
    plt.show()

# %%
# https://github.com/gzuidhof/luna16/blob/master/src/data_processing/create_same_spacing_data_NODULE.py
